# %%
import torch
import tensorflow as tf
import pandas
import matplotlib.pyplot as plt

# %%
top_mnist_pt_nofool = torch.load('../../mnist_nofool/top_pt_model', map_location=torch.device('cpu'))
bottom_mnist_pt_nofool = torch.load('../../mnist_nofool/bottom_pt_model', map_location=torch.device('cpu'))

# %%
top_mnist_pt = torch.load('../../mnist/top_pt_model', map_location=torch.device('cpu'))
bottom_mnist_pt = torch.load('../../mnist/bottom_pt_model', map_location=torch.device('cpu'))

# %%
top_mnist_tf_nofool = tf.keras.models.load_model('../../mnist_nofool/top_tf_model/')
bottom_mnist_tf_nofool = tf.keras.models.load_model('../../mnist_nofool/bottom_tf_model/')

# %%
top_mnist_tf = tf.keras.models.load_model('../../mnist/top_tf_model/')
bottom_mnist_tf = tf.keras.models.load_model('../../mnist/bottom_tf_model/')

# %%
ax = plt.gca()
ax.plot(list(range(10)), list(top_mnist_pt_nofool.parameters())[-1].detach().numpy(), color="blue", label="Top PyTorch NoFool", linestyle="dashed")
ax.plot(list(range(10)), list(top_mnist_pt.parameters())[-1].detach().numpy(), color="blue", label="Top PyTorch w/ Fool")
ax.plot(list(range(10)), top_mnist_tf_nofool.weights[-1].numpy(), color="red", label="Top TensorFlow NoFool", linestyle="dashed")
ax.plot(list(range(10)), top_mnist_tf.weights[-1].numpy(), color="red", label="Top TensorFlow w/ Fool")
ax.plot(list(range(10)), list(bottom_mnist_pt_nofool.parameters())[-1].detach().numpy(), color="green", label="Bottom PyTorch NoFool", linestyle="dashed")
ax.plot(list(range(10)), list(bottom_mnist_pt.parameters())[-1].detach().numpy(), color="green", label="Bottom PyTorch w/ Fool")
ax.plot(list(range(10)), bottom_mnist_tf_nofool.weights[-1].numpy(), color="orange", label="Bottom TensorFlow NoFool", linestyle="dashed")
ax.plot(list(range(10)), bottom_mnist_tf.weights[-1].numpy(), color="orange", label="Bottom TensorFlow w/ Fool")
#ax.set_title("MNIST Classifier: Output Layer Weights for Best and Worst Hyperparameters")
ax.set_xlabel("Output Neuron Number")
ax.set_ylabel("Weight")
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.20),
          fancybox=True, shadow=True, ncol=4)
plt.show()
