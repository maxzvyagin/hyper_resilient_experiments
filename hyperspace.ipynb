# %% [markdown]
# ### Testing out Hyperspace on MNIST Data - Model Resiliency Test

# %%
# !conda install mpi4py -y

# %%
# !brew install libopenmpi-dev
# Out:
# Updating Homebrew...

# %%
# !pip install ~/Documents/hyperspace/.
# Out:
# Processing /Users/mzvyagin/Documents/hyperspace
# ...
#   Using cached mpi4py-3.0.3.tar.gz (1.4 MB)
# ...
#   Using cached Cython-0.29.21-cp38-cp38-macosx_10_9_x86_64.whl (1.9 MB)
# ...
#   Using cached sphinxcontrib_bibtex-1.0.0-py3-none-any.whl (14 kB)
# ...
#   Using cached Sphinx-3.2.1-py3-none-any.whl (2.9 MB)
# Processing /Users/mzvyagin/Library/Caches/pip/wheels/4b/45/f0/539392231d8865c5c32eab3f775f7e8071f47a419c2b0babb4/oset-0.1.3-py3-none-any.whl
# ...
#   Using cached pybtex_docutils-0.2.2-py2.py3-none-any.whl (4.6 kB)
# ...
#   Using cached pybtex-0.22.2-py2.py3-none-any.whl (279 kB)
# ...
#   Using cached sphinxcontrib_htmlhelp-1.0.3-py2.py3-none-any.whl (96 kB)
# ...
#   Using cached Babel-2.8.0-py2.py3-none-any.whl (8.6 MB)
# ...
#   Using cached sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
# ...
#   Using cached imagesize-1.2.0-py2.py3-none-any.whl (4.8 kB)
# ...
#   Using cached sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
# ...
#   Using cached alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# ...

# %%
from hyperspace import create_hyperspace

# %%
# !which python
