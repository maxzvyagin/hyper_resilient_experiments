# %%
import pandas as pd

# %%
res = pd.read_csv('../multi_model_multi_metric_results3.csv')

# %%
res.head()
# Out:
#    trial_id  pt_test_acc  tf_test_acc  pt_uniform_accuracy  \
# 0  7adc2a28     0.224161       0.9374             0.848346
# 1  7adcae30     0.671889       0.7823             0.467043
# 2  7add0bd2     0.254160       0.9313             0.764996
# 3  7add53c6     0.607595       0.8204             0.600869
# 4  7add8bac     0.832933       0.7833             0.407213
#
#    tf_uniform_accuracy  pt_gaussian_accuracy  tf_gaussian_accuracy  \
# 0             0.899761              0.848346              0.900757
# 1             0.724065              0.463656              0.728017
# 2             0.948718              0.762997              0.949541
# 3             0.816036              0.602449              0.820184
# 4             0.781867              0.401771              0.785003
#
#    pt_saltandpepper_accuracy  tf_saltandpepper_accuracy  average_res  ...  \
# 0                   0.859107                   0.898764     0.802080  ...
# ...

# %%
sorted_res = res.sort_values('average_res', ascending=False)

# %%
sorted_res.head()
# Out:
#      trial_id  pt_test_acc  tf_test_acc  pt_uniform_accuracy  \
# 753  746aa550     0.022471       0.9729             0.997159
# 778  746f5e42     0.057236       0.9662             0.988814
# 157  d7951c42     0.010276       0.9771             0.995752
# 174  d7983008     0.046016       0.9707             0.980520
# 185  d79a1daa     0.030534       0.9807             0.983774
#
#      tf_uniform_accuracy  pt_gaussian_accuracy  tf_gaussian_accuracy  \
# 753             1.000000              0.996550              1.000000
# 778             1.000000              0.987588              1.000000
# 157             1.000000              0.995752              1.000000
# 174             0.999668              0.983619              0.999779
# 185             1.000000              0.983053              1.000000
#
#      pt_saltandpepper_accuracy  tf_saltandpepper_accuracy  average_res  ...  \
# 753                   0.995332                   1.000000     0.873051  ...
# ...
