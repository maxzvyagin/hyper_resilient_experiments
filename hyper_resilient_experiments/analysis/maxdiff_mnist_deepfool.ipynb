# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../max_diff_with_deepfool_mnist2.csv')

# %%
sorted_df = df.sort_values('average_res', ascending=False)

# %%
sorted_df.head()
# Out:
#      trial_id  pt_test_acc  pt_deepfool_accuracy  tf_test_acc  \
# 44   645a5f06     0.752900              0.547123       0.7740
# 264  8a2dd07e     0.859189              0.619924       0.8562
# 163  6347a6b7     0.933680              0.674540       0.9268
# 243  ef3cac39     0.808974              0.578928       0.8317
# 156  96b9ecd8     0.953478              0.687407       0.9511
#
#      tf_deepfool_accuracy  average_res  time_this_iter_s  done  \
# 44               0.560692     0.017335          0.009301  True
# 264              0.594187     0.014363          0.007409  True
# 163              0.664252     0.008584          0.006582  True
# 243              0.571918     0.007858          0.007227  True
# 156              0.675741     0.007022          0.008284  True
#
#      timesteps_total  episodes_total  ...        node_ip time_since_restore  \
# 44               NaN             NaN  ...  140.221.79.13       10791.910271
# ...
