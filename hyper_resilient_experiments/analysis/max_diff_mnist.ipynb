# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
max_diff = pd.read_csv('../max_diff_mnist_10trials.csv')

# %%
max_diff
# Out:
#      trial_id  pt_test_acc  tf_test_acc  average_res  time_this_iter_s  done  \
# 0    e251fe48     0.961587       0.9645     0.002913        209.899698  True
# 1    e251fe49     0.963900       0.9637     0.000200        271.327291  True
# 2    e251fe4a     0.976892       0.9768     0.000092        212.128652  True
# 3    e251fe4b     0.977343       0.9773     0.000043        266.464995  True
# 4    e251fe4c     0.948754       0.9512     0.002446        271.891354  True
# ..        ...          ...          ...          ...               ...   ...
# 305  1031b729     0.982563       0.9814     0.001163        705.184789  True
# 306  1031b72a     0.981204       0.9815     0.000296        171.601361  True
# 307  1031b72b     0.977583       0.9780     0.000417        203.503656  True
# 308  1031b72c     0.977340       0.9765     0.000840        281.487431  True
# 309  1031b72d     0.974677       0.9757     0.001023        118.144995  True
#
# ...

# %%
sorted_df = max_diff.sort_values('average_res', ascending=False)

# %%
sorted_df
# Out:
#      trial_id  pt_test_acc  tf_test_acc  average_res  time_this_iter_s  done  \
# 246  05079e2a     0.618364       0.5230     0.095364         31.188619  True
# 290  a014fb14     0.650073       0.7246     0.074527        292.892122  True
# 139  7cebe781     0.782449       0.8534     0.070951        861.404672  True
# 155  f94bea6d     0.781300       0.8186     0.037300        239.388367  True
# 273  0a6196bd     0.769097       0.7944     0.025303         48.932761  True
# ..        ...          ...          ...          ...               ...   ...
# 3    e251fe4b     0.977343       0.9773     0.000043        266.464995  True
# 253  1074f47f     0.979878       0.9799     0.000022        169.889727  True
# 275  0a6196bf     0.975122       0.9751     0.000022        101.193116  True
# 44   7a8ce85a     0.970879       0.9709     0.000021        161.583872  True
# 87   2d21e333     0.981109       0.9811     0.000009        246.397466  True
#
# ...

# %%
plt.scatter(max_diff['config.learning_rate'], max_diff['average_res'])
