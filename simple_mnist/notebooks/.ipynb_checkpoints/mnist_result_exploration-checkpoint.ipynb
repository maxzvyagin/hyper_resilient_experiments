# %% [markdown]
# ### MNIST Result Exploration
# Purpose of this notebook:
# - Find out if there are configurations for which one framework is resilient and another isn't
# - Find out if there are configuration for which both frameworks have high accuracy, but low resiliency

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = pd.read_csv("../old_data_and_files/multi_model_multi_metric_results_50samples_iotagpu.csv")

# %%
len(results)
# Out:
# 800

# %%
results.head()
# Out:
#    trial_id  pt_test_acc  tf_test_acc  pt_uniform_accuracy  \
# 0  6a58d18e     0.827171       0.6188             0.490627
# 1  6a5a2854     0.531257       0.4011             0.273756
# 2  6a5aa8f6     0.885748       0.9132             0.739952
# 3  6a5ad9ac     0.933856       0.9273             0.736809
# 4  6a5b0df0     0.844316       0.8229             0.492658
#
#    tf_uniform_accuracy  pt_gaussian_accuracy  tf_gaussian_accuracy  \
# 0             0.788839              0.485133              0.791640
# 1             0.400452              0.271170              0.400452
# 2             0.898855              0.739420              0.900719
# 3             0.941730              0.737165              0.944129
# 4             0.842167              0.484197              0.846154
#
#    pt_saltandpepper_accuracy  tf_saltandpepper_accuracy  average_res  ...  \
# 0                   0.505602                   0.797996     0.663226  ...
# 1                   0.275695                   0.400560     0.369305  ...
# 2                   0.769231                   0.901251     0.843547  ...
# 3                   0.746403                   0.936756     0.863018  ...
# 4                   0.498784                   0.844306     0.709435  ...
#
#     hostname       node_ip  time_since_restore  timesteps_since_restore  \
# 0  iotagpu02  140.221.68.6          335.161301                        0
# 1  iotagpu02  140.221.68.6          419.606244                        0
# 2  iotagpu02  140.221.68.6          305.104492                        0
# 3  iotagpu02  140.221.68.6          252.207514                        0
# 4  iotagpu02  140.221.68.6          247.868385                        0
#
#    iterations_since_restore  \
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         1
#
#                                       experiment_tag config.learning_rate  \
# 0  1_batch_size=714,dropout=0.61279,epochs=69,lea...             0.080155
# 1  2_batch_size=714,dropout=0.83736,epochs=88,lea...             0.063934
# 2  3_batch_size=578,dropout=0.52074,epochs=62,lea...             0.069067
# 3  4_batch_size=866,dropout=0.59443,epochs=53,lea...             0.062085
# 4  5_batch_size=791,dropout=0.64746,epochs=51,lea...             0.081445
#
#    config.dropout  config.epochs  config.batch_size
# 0        0.612793             69                714
# 1        0.837360             88                714
# 2        0.520743             62                578
# 3        0.594432             53                866
# 4        0.647460             51                791
#
# [5 rows x 30 columns]

# %%
results['average_pt_resiliency'] = (results['pt_uniform_accuracy']+results['pt_gaussian_accuracy']+results['pt_saltandpepper_accuracy'])/3

# %%
results['average_tf_resiliency'] = (results['tf_uniform_accuracy']+results['tf_gaussian_accuracy']+results['tf_saltandpepper_accuracy'])/3

# %%
results['resiliency_difference'] = results['average_pt_resiliency'] - results['average_tf_resiliency']

# %%
results.head()
# Out:
#    trial_id  pt_test_acc  tf_test_acc  pt_uniform_accuracy  \
# 0  6a58d18e     0.827171       0.6188             0.490627
# 1  6a5a2854     0.531257       0.4011             0.273756
# 2  6a5aa8f6     0.885748       0.9132             0.739952
# 3  6a5ad9ac     0.933856       0.9273             0.736809
# 4  6a5b0df0     0.844316       0.8229             0.492658
#
#    tf_uniform_accuracy  pt_gaussian_accuracy  tf_gaussian_accuracy  \
# 0             0.788839              0.485133              0.791640
# 1             0.400452              0.271170              0.400452
# 2             0.898855              0.739420              0.900719
# 3             0.941730              0.737165              0.944129
# 4             0.842167              0.484197              0.846154
#
#    pt_saltandpepper_accuracy  tf_saltandpepper_accuracy  average_res  ...  \
# 0                   0.505602                   0.797996     0.663226  ...
# 1                   0.275695                   0.400560     0.369305  ...
# 2                   0.769231                   0.901251     0.843547  ...
# 3                   0.746403                   0.936756     0.863018  ...
# 4                   0.498784                   0.844306     0.709435  ...
#
#    timesteps_since_restore  iterations_since_restore  \
# 0                        0                         1
# 1                        0                         1
# 2                        0                         1
# 3                        0                         1
# 4                        0                         1
#
#                                       experiment_tag  config.learning_rate  \
# 0  1_batch_size=714,dropout=0.61279,epochs=69,lea...              0.080155
# 1  2_batch_size=714,dropout=0.83736,epochs=88,lea...              0.063934
# 2  3_batch_size=578,dropout=0.52074,epochs=62,lea...              0.069067
# 3  4_batch_size=866,dropout=0.59443,epochs=53,lea...              0.062085
# 4  5_batch_size=791,dropout=0.64746,epochs=51,lea...              0.081445
#
#    config.dropout config.epochs config.batch_size  average_pt_resiliency  \
# 0        0.612793            69               714               0.493787
# 1        0.837360            88               714               0.273540
# 2        0.520743            62               578               0.749534
# 3        0.594432            53               866               0.740126
# 4        0.647460            51               791               0.491880
#
#    average_tf_resiliency  resiliency_difference
# 0               0.792825              -0.299038
# 1               0.400488              -0.126948
# 2               0.900275              -0.150741
# 3               0.940872              -0.200746
# 4               0.844209              -0.352329
#
# [5 rows x 33 columns]

# %%
biggest_resiliency_difference = results.sort_values('resiliency_difference')

# %%
biggest_resiliency_difference.head()
# Out:
#      trial_id  pt_test_acc  tf_test_acc  pt_uniform_accuracy  \
# 211  be14ae90     0.541197       0.5841             0.204111
# 57   fab995ba     0.654049       0.6700             0.238494
# 649  3708a6ce     0.339323       0.5432             0.197749
# 657  6d8ffaae     0.634479       0.6239             0.262943
# 54   fab90ad2     0.582391       0.5423             0.171589
#
#      tf_uniform_accuracy  pt_gaussian_accuracy  tf_gaussian_accuracy  \
# 211             0.800467              0.207971              0.800467
# 57              0.795089              0.242072              0.795902
# 649             0.746910              0.201992              0.749124
# 657             0.799281              0.262453              0.800425
# 54              0.688416              0.176854              0.688988
#
#      pt_saltandpepper_accuracy  tf_saltandpepper_accuracy  average_res  ...  \
# 211                   0.210843                   0.800467     0.518703  ...
# 57                    0.247601                   0.800049     0.555407  ...
# 649                   0.201070                   0.750600     0.466246  ...
# 657                   0.281071                   0.802548     0.558387  ...
# 54                    0.176854                   0.694483     0.465234  ...
#
#      timesteps_since_restore  iterations_since_restore  \
# 211                        0                         1
# 57                         0                         1
# 649                        0                         1
# 657                        0                         1
# 54                         0                         1
#
#                                         experiment_tag  config.learning_rate  \
# 211  12_batch_size=857,dropout=0.83233,epochs=24,le...              0.067956
# 57   8_batch_size=946,dropout=0.89638,epochs=57,lea...              0.043290
# 649  50_batch_size=417,dropout=0.70964,epochs=21,le...              0.099066
# 657  8_batch_size=471,dropout=0.81118,epochs=64,lea...              0.053146
# 54   5_batch_size=672,dropout=0.85492,epochs=53,lea...              0.060478
#
#      config.dropout config.epochs config.batch_size  average_pt_resiliency  \
# 211        0.832334            24               857               0.207641
# 57         0.896381            57               946               0.242722
# 649        0.709640            21               417               0.200271
# 657        0.811180            64               471               0.268822
# 54         0.854921            53               672               0.175099
#
#      average_tf_resiliency  resiliency_difference
# 211               0.800467              -0.592825
# 57                0.797013              -0.554291
# 649               0.748878              -0.548607
# 657               0.800751              -0.531929
# 54                0.690629              -0.515530
#
# [5 rows x 33 columns]

# %%
biggest_resiliency_difference.tail()
# Out:
#      trial_id  pt_test_acc  tf_test_acc  pt_uniform_accuracy  \
# 313  49db464a     0.974585       0.9608             0.973269
# 369  9e6bf6ac     0.994133       0.9742             0.988203
# 498  82c366e2     0.618153       0.5187             0.539788
# 529  74d03e26     0.696530       0.6858             0.682024
# 568  537854c8     0.589117       0.5235             0.565934
#
#      tf_uniform_accuracy  pt_gaussian_accuracy  tf_gaussian_accuracy  \
# 313             0.899779              0.973106              0.900025
# 369             0.903223              0.989449              0.903798
# 498             0.420424              0.531830              0.427056
# 529             0.544632              0.687783              0.546277
# 568             0.428571              0.587912              0.428571
#
#      pt_saltandpepper_accuracy  tf_saltandpepper_accuracy  average_res  ...  \
# 313                   0.975149                   0.888907     0.943202  ...
# 369                   0.987531                   0.900249     0.955098  ...
# 498                   0.547745                   0.424403     0.503512  ...
# 529                   0.698478                   0.550802     0.636541  ...
# 568                   0.587912                   0.423077     0.516824  ...
#
#      timesteps_since_restore  iterations_since_restore  \
# 313                        0                         1
# 369                        0                         1
# 498                        0                         1
# 529                        0                         1
# 568                        0                         1
#
#                                         experiment_tag  config.learning_rate  \
# 313  14_batch_size=941,dropout=0.20162,epochs=29,le...              0.052437
# 369  20_batch_size=802,dropout=0.41486,epochs=53,le...              0.013421
# 498  49_batch_size=58,dropout=0.65167,epochs=56,lea...              0.052202
# 529  30_batch_size=187,dropout=0.3685,epochs=92,lea...              0.091067
# 568  19_batch_size=14,dropout=0.36295,epochs=44,lea...              0.049795
#
#      config.dropout config.epochs config.batch_size  average_pt_resiliency  \
# 313        0.201616            29               941               0.973841
# 369        0.414858            53               802               0.988394
# 498        0.651668            56                58               0.539788
# 529        0.368498            92               187               0.689428
# 568        0.362949            44                14               0.580586
#
#      average_tf_resiliency  resiliency_difference
# 313               0.896237               0.077604
# 369               0.902423               0.085971
# 498               0.423961               0.115827
# 529               0.547237               0.142191
# 568               0.426740               0.153846
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Is model accuracy entirely based off of epochs?

# %%
plt.scatter(results['config.epochs'], results['pt_test_acc'])

# %%
plt.scatter(results['config.epochs'], results['tf_test_acc'])

# %% [markdown]
# ### Top configurations where test accuracy is high, but resiliency is low

# %%
results['average_test_accuracy'] = (results['pt_test_acc']+results['tf_test_acc'])/2

# %%
results['average_resiliency'] = (results['average_pt_resiliency']+results['average_tf_resiliency'])/2

# %%
plt.scatter(results['average_test_accuracy'])
