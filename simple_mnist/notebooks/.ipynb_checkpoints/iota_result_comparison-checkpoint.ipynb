# %%
import pandas as pd

# %%
first_res = pd.read_csv("../multi_model_multi_metric_results_50samples.csv")

# %%
second_res = pd.read_csv("../multi_model_multi_metric_results_50samples_iotagpu.csv")

# %%
first_res_sorted = first_res.sort_values('average_res', ascending=False)
first_res_sorted = first_res_sorted.reset_index(drop=True)

# %%
second_res_sorted = second_res.sort_values('average_res')
second_res_sorted = second_res.reset_index(drop=True)

# %%
first_res_sorted.head()
# Out:
#    trial_id  pt_test_acc  tf_test_acc  pt_uniform_accuracy  \
# 0  d11fa67e     0.098822       0.1028             0.044776
# 1  807946ca     0.115931       0.1321             0.100993
# 2  44b37ac4     0.150513       0.1028             0.061966
# 3  de73a89c     0.098633       0.0980             0.050000
# 4  d11cb46e     0.106483       0.1028             0.100000
#
#    tf_uniform_accuracy  pt_gaussian_accuracy  tf_gaussian_accuracy  \
# 0             0.104478              0.044776              0.104478
# 1             0.051325              0.100993              0.051325
# 2             0.097222              0.067308              0.097222
# 3             0.150000              0.050000              0.150000
# 4             0.100000              0.100000              0.100000
#
#    pt_saltandpepper_accuracy  tf_saltandpepper_accuracy  average_res  ...  \
# 0                   0.044776                   0.104478     0.081173  ...
# 1                   0.100993                   0.051325     0.088123  ...
# 2                   0.070513                   0.097222     0.093096  ...
# 3                   0.050000                   0.150000     0.099579  ...
# 4                   0.100000                   0.100000     0.101160  ...
#
#     hostname       node_ip  time_since_restore  timesteps_since_restore  \
# 0  iotagpu02  140.221.68.6          521.556700                        0
# 1  iotagpu02  140.221.68.6          415.407106                        0
# 2  iotagpu02  140.221.68.6          352.766173                        0
# 3  iotagpu02  140.221.68.6          320.834164                        0
# 4  iotagpu02  140.221.68.6          747.886587                        0
#
#    iterations_since_restore  \
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         1
#
#                                       experiment_tag config.learning_rate  \
# 0  26_batch_size=67,dropout=0.88473,epochs=68,lea...             0.099493
# 1  14_batch_size=604,dropout=0.89302,epochs=85,le...             0.086946
# 2  28_batch_size=72,dropout=0.84538,epochs=47,lea...             0.060203
# 3  42_batch_size=100,dropout=0.89965,epochs=49,le...             0.082187
# 4  10_batch_size=60,dropout=0.84696,epochs=95,lea...             0.088616
#
#    config.dropout  config.epochs  config.batch_size
# 0        0.884730             68                 67
# 1        0.893016             85                604
# 2        0.845378             47                 72
# 3        0.899646             49                100
# 4        0.846961             95                 60
#
# [5 rows x 30 columns]

# %%
second_res_sorted.head()
# Out:
#    trial_id  pt_test_acc  tf_test_acc  pt_uniform_accuracy  \
# 0  6a58d18e     0.827171       0.6188             0.490627
# 1  6a5a2854     0.531257       0.4011             0.273756
# 2  6a5aa8f6     0.885748       0.9132             0.739952
# 3  6a5ad9ac     0.933856       0.9273             0.736809
# 4  6a5b0df0     0.844316       0.8229             0.492658
#
#    tf_uniform_accuracy  pt_gaussian_accuracy  tf_gaussian_accuracy  \
# 0             0.788839              0.485133              0.791640
# 1             0.400452              0.271170              0.400452
# 2             0.898855              0.739420              0.900719
# 3             0.941730              0.737165              0.944129
# 4             0.842167              0.484197              0.846154
#
#    pt_saltandpepper_accuracy  tf_saltandpepper_accuracy  average_res  ...  \
# 0                   0.505602                   0.797996     0.663226  ...
# 1                   0.275695                   0.400560     0.369305  ...
# 2                   0.769231                   0.901251     0.843547  ...
# 3                   0.746403                   0.936756     0.863018  ...
# 4                   0.498784                   0.844306     0.709435  ...
#
#     hostname       node_ip  time_since_restore  timesteps_since_restore  \
# 0  iotagpu02  140.221.68.6          335.161301                        0
# 1  iotagpu02  140.221.68.6          419.606244                        0
# 2  iotagpu02  140.221.68.6          305.104492                        0
# 3  iotagpu02  140.221.68.6          252.207514                        0
# 4  iotagpu02  140.221.68.6          247.868385                        0
#
#    iterations_since_restore  \
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         1
#
#                                       experiment_tag config.learning_rate  \
# 0  1_batch_size=714,dropout=0.61279,epochs=69,lea...             0.080155
# 1  2_batch_size=714,dropout=0.83736,epochs=88,lea...             0.063934
# 2  3_batch_size=578,dropout=0.52074,epochs=62,lea...             0.069067
# 3  4_batch_size=866,dropout=0.59443,epochs=53,lea...             0.062085
# 4  5_batch_size=791,dropout=0.64746,epochs=51,lea...             0.081445
#
#    config.dropout  config.epochs  config.batch_size
# 0        0.612793             69                714
# 1        0.837360             88                714
# 2        0.520743             62                578
# 3        0.594432             53                866
# 4        0.647460             51                791
#
# [5 rows x 30 columns]
